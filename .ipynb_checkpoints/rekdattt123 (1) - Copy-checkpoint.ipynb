# %% [markdown]
# ### INSTALL & LIBRARY

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.21.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (1.1.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (3.6.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (1.23.4)
# Requirement already satisfied: setuptools in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (65.5.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from mlxtend) (1.9.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\abc\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import requests 
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori
from datetime import datetime, timedelta


pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Convert to csv

# %%
df_traffic_load = pd.read_csv('traffic_accident_final.csv')
df_traffic_load['date_time'] = pd.to_datetime(df_traffic_load['date_time'])

# %%
df_traffic_load.drop(['id_str','full_text'], axis=1, inplace=True)
df_traffic_load
# Out:
#                 date_time
# 0     2020-01-01 00:00:00
# 1     2020-01-01 00:00:00
# 2     2020-01-01 00:00:00
# 3     2020-01-01 00:00:00
# 4     2020-01-01 00:00:00
# ...                   ...
# 41623 2020-03-31 23:00:00
# 41624 2020-03-31 23:00:00
# 41625 2020-03-31 23:00:00
# 41626 2020-03-31 23:00:00
# 41627 2020-03-31 23:00:00
#
# [41628 rows x 1 columns]

# %%
df_traffic_load.value_counts()
# Out:
# date_time
# 2020-01-27 06:00:00    227
# 2020-01-27 08:00:00    221
# 2020-01-27 10:00:00    203
# 2020-01-27 07:00:00    185
# 2020-01-27 09:00:00    181
#                       ...
# 2020-03-26 02:00:00      1
# 2020-02-25 04:00:00      1
# 2020-03-28 03:00:00      1
# 2020-03-27 01:00:00      1
# 2020-02-24 01:00:00      1
# Length: 2183, dtype: int64

# %%
df = df_traffic_load.groupby('date_time', as_index=False).value_counts()
df
# Out:
#                date_time  count
# 0    2020-01-01 00:00:00     16
# 1    2020-01-01 01:00:00     17
# 2    2020-01-01 02:00:00     11
# 3    2020-01-01 03:00:00     13
# 4    2020-01-01 04:00:00      5
# ...                  ...    ...
# 2178 2020-03-31 19:00:00     33
# 2179 2020-03-31 20:00:00     18
# 2180 2020-03-31 21:00:00     21
# 2181 2020-03-31 22:00:00     19
# 2182 2020-03-31 23:00:00     18
#
# [2183 rows x 2 columns]

# %%
range = []
for row in df['count']:
    if row > 50.0 : range.append('Critical')
    elif row > 20.0 : range.append('Significant')
    elif row > 5.0 : range.append('Considerable')
    elif row > 0 or np.nan: range.append('No or Low')

df['count'] = range

df.rename(columns = {'count':'impact'}, inplace = True)

# %%
df
# Out:
#                date_time        impact
# 0    2020-01-01 00:00:00  Considerable
# 1    2020-01-01 01:00:00  Considerable
# 2    2020-01-01 02:00:00  Considerable
# 3    2020-01-01 03:00:00  Considerable
# 4    2020-01-01 04:00:00     No or Low
# ...                  ...           ...
# 2178 2020-03-31 19:00:00   Significant
# 2179 2020-03-31 20:00:00  Considerable
# 2180 2020-03-31 21:00:00   Significant
# 2181 2020-03-31 22:00:00  Considerable
# 2182 2020-03-31 23:00:00  Considerable
#
# [2183 rows x 2 columns]

# %%
df['impact'].value_counts()
# Out:
# Considerable    1160
# Significant      731
# No or Low        232
# Critical          60
# Name: impact, dtype: int64

# %% [markdown]
# ## DF Weather

# %%
df_weather_load = pd.read_csv('weather.csv')

# %%
df_weather_load['date_time'] = pd.to_datetime(df_weather_load['date_time'])
df_weather_load
# Out:
#                date_time            weatherValue
# 0    2020-01-01 00:00:00  Torrential rain shower
# 1    2020-01-01 01:00:00  Torrential rain shower
# 2    2020-01-01 02:00:00              Heavy rain
# 3    2020-01-01 03:00:00              Heavy rain
# 4    2020-01-01 04:00:00              Heavy rain
# ...                  ...                     ...
# 2155 2020-03-30 19:00:00    Patchy rain possible
# 2156 2020-03-30 20:00:00  Torrential rain shower
# 2157 2020-03-30 21:00:00  Torrential rain shower
# 2158 2020-03-30 22:00:00  Torrential rain shower
# 2159 2020-03-30 23:00:00       Patchy light rain
#
# [2160 rows x 2 columns]

# %%
df_weather_load.weatherValue.unique()
# Out:
# array(['Torrential rain shower', 'Heavy rain',
#        'Moderate or heavy rain shower', 'Light rain',
#        'Patchy light drizzle', 'Light rain shower', 'Partly cloudy',
#        'Patchy rain possible', 'Cloudy', 'Patchy light rain',
#        'Heavy rain at times', 'Overcast', 'Moderate rain',
#        'Moderate rain at times', 'Light drizzle'], dtype=object)

# %%
df_weather = df_weather_load.copy()
range = []
for row in df_weather['weatherValue']:
    if row == 'Light rain shower' : range.append('Light rain')
    elif row == 'Patchy light rain' : range.append('Light rain')
    elif row == 'Patchy light drizzle' : range.append('Light rain')
    elif row == 'Moderate or heavy rain shower' : range.append('Moderate rain')
    elif row == 'Moderate rain at times' : range.append('Moderate rain')
    elif row == 'Heavy rain at times' : range.append('Heavy rain')
    elif row == 'Torrential rain shower' : range.append('Heavy rain')
    elif row == 'Partly cloudy' : range.append('Sunny')
    elif row == 'Cloudy' : range.append('Overcast')
    elif row or np.nan == 'Patchy rain possible' : range.append('Moderate rain')

df_weather ['weatherValue'] = range
df_weather
# Out:
#                date_time   weatherValue
# 0    2020-01-01 00:00:00     Heavy rain
# 1    2020-01-01 01:00:00     Heavy rain
# 2    2020-01-01 02:00:00  Moderate rain
# 3    2020-01-01 03:00:00  Moderate rain
# 4    2020-01-01 04:00:00  Moderate rain
# ...                  ...            ...
# 2155 2020-03-30 19:00:00  Moderate rain
# 2156 2020-03-30 20:00:00     Heavy rain
# 2157 2020-03-30 21:00:00     Heavy rain
# 2158 2020-03-30 22:00:00     Heavy rain
# 2159 2020-03-30 23:00:00     Light rain
#
# [2160 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# date_time    0
# impact       0
# dtype: int64

# %% [markdown]
# ## ASOSIASI

# %%
import atoti as tt
# Out:
# Welcome to atoti 0.7.1!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
session = tt.Session()

# %%
ttTraffic = session.read_pandas(df,
                              keys=["date_time","impact"],
                              table_name="table_Traffic")

# %%
ttTraffic.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2020-01-01 00:00:00, Considerable), (2020-01-01 07:00:00, Considerable), (2020-01-01 12:00:00, Considerable), (2020-01-01 16:00:00, Considerable), (2020-01-02 15:00:00, Significant)]

# %%
ttWeather = session.read_pandas(df_weather,
                              keys=["date_time","weatherValue"],
                              table_name="table_Weather")

# %%
ttWeather.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2020-01-01 00:00:00, Heavy rain), (2020-01-01 12:00:00, Heavy rain), (2020-01-01 16:00:00, Heavy rain), (2020-01-01 23:00:00, Moderate rain), (2020-01-02 15:00:00, Light rain)]

# %% [markdown]
# ## Membuat Data Cube

# %%
ttWeather.join(ttTraffic, mapping={'date_time': 'date_time'})
cube1 = session.create_cube(ttWeather)

h, l, m = cube1.hierarchies, cube1.levels, cube1.measures

# %%
cube1
# Out:
# Cube(_name='table_Weather', _hierarchies=Hierarchies(_create_hierarchy_from_arguments=<bound method Cube._create_hierarchy_from_arguments of ...>, _cube_name='table_Weather'), _measures=Measures())

# %%
h
# Out:
# Hierarchies(_create_hierarchy_from_arguments=<bound method Cube._create_hierarchy_from_arguments of Cube(_name='table_Weather', _hierarchies=..., _measures=Measures())>, _cube_name='table_Weather')

# %%
l
# Out:
# Levels()

# %%
m
# Out:
# Measures()

# %% [markdown]
# Session visualizasda

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# #### Merge

# %%
df_merge = pd.merge(df, df_weather_load, left_on='date_time', right_on='date_time')

# %%
df_merge
# Out:
#                date_time        impact            weatherValue
# 0    2020-01-01 00:00:00  Considerable  Torrential rain shower
# 1    2020-01-01 01:00:00  Considerable  Torrential rain shower
# 2    2020-01-01 02:00:00  Considerable              Heavy rain
# 3    2020-01-01 03:00:00  Considerable              Heavy rain
# 4    2020-01-01 04:00:00     No or Low              Heavy rain
# ...                  ...           ...                     ...
# 2154 2020-03-30 19:00:00  Considerable    Patchy rain possible
# 2155 2020-03-30 20:00:00   Significant  Torrential rain shower
# 2156 2020-03-30 21:00:00  Considerable  Torrential rain shower
# 2157 2020-03-30 22:00:00  Considerable  Torrential rain shower
# 2158 2020-03-30 23:00:00  Considerable       Patchy light rain
#
# [2159 rows x 3 columns]

# %%
df_merge.isna().sum()
# Out:
# date_time       0
# impact          0
# weatherValue    0
# dtype: int64

# %% [markdown]
# #### Melakukan Association Rule Mining dengan Algoritma Apriori dan Library Mlextend

# %%
df_filter = pd.pivot_table(df_merge, values=['impact'], index=['weatherValue'], columns=['date_time'], aggfunc=np.sum)

# %%
df_filter
# Out:
#                                            impact                      \
# date_time                     2020-01-01 00:00:00 2020-01-01 01:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                                    NaN                 NaN
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower               Considerable        Considerable
#
#                                                                        \
# date_time                     2020-01-01 02:00:00 2020-01-01 03:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                           Considerable        Considerable
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower                        NaN                 NaN
#
#                                                                        \
# date_time                     2020-01-01 04:00:00 2020-01-01 05:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                              No or Low        Considerable
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower                        NaN                 NaN
#
#                                                                        \
# date_time                     2020-01-01 06:00:00 2020-01-01 07:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                           Considerable        Considerable
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower                        NaN                 NaN
#
#                                                                        ...  \
# date_time                     2020-01-01 08:00:00 2020-01-01 09:00:00  ...
# weatherValue                                                           ...
# Cloudy                                        NaN                 NaN  ...
# Heavy rain                           Considerable        Considerable  ...
# Heavy rain at times                           NaN                 NaN  ...
# Light drizzle                                 NaN                 NaN  ...
# Light rain                                    NaN                 NaN  ...
# Light rain shower                             NaN                 NaN  ...
# Moderate or heavy rain shower                 NaN                 NaN  ...
# Moderate rain                                 NaN                 NaN  ...
# Moderate rain at times                        NaN                 NaN  ...
# Overcast                                      NaN                 NaN  ...
# Partly cloudy                                 NaN                 NaN  ...
# Patchy light drizzle                          NaN                 NaN  ...
# Patchy light rain                             NaN                 NaN  ...
# Patchy rain possible                          NaN                 NaN  ...
# Torrential rain shower                        NaN                 NaN  ...
#
#                                                                        \
# date_time                     2020-03-30 14:00:00 2020-03-30 15:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                                    NaN                 NaN
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                        Considerable        Considerable
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower                        NaN                 NaN
#
#                                                                        \
# date_time                     2020-03-30 16:00:00 2020-03-30 17:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                                    NaN                 NaN
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                        Considerable                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN         Significant
# Torrential rain shower                        NaN                 NaN
#
#                                                                        \
# date_time                     2020-03-30 18:00:00 2020-03-30 19:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                                    NaN                 NaN
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                 Considerable        Considerable
# Torrential rain shower                        NaN                 NaN
#
#                                                                        \
# date_time                     2020-03-30 20:00:00 2020-03-30 21:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                                    NaN                 NaN
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN                 NaN
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower                Significant        Considerable
#
#
# date_time                     2020-03-30 22:00:00 2020-03-30 23:00:00
# weatherValue
# Cloudy                                        NaN                 NaN
# Heavy rain                                    NaN                 NaN
# Heavy rain at times                           NaN                 NaN
# Light drizzle                                 NaN                 NaN
# Light rain                                    NaN                 NaN
# Light rain shower                             NaN                 NaN
# Moderate or heavy rain shower                 NaN                 NaN
# Moderate rain                                 NaN                 NaN
# Moderate rain at times                        NaN                 NaN
# Overcast                                      NaN                 NaN
# Partly cloudy                                 NaN                 NaN
# Patchy light drizzle                          NaN                 NaN
# Patchy light rain                             NaN        Considerable
# Patchy rain possible                          NaN                 NaN
# Torrential rain shower               Considerable                 NaN
#
# [15 rows x 2159 columns]

# %%
del range

# %%
itemsetList = []
dflist = df_filter.values.tolist()
dfindex = df_filter.index.tolist()

for i in range (len(df_filter)):
    currentList = [dflist[i][item] for item in range(len(dflist[i])) if not(pd.isnull(dflist[i][item])) == True]
    itemsetList.append(currentList)
    
# itemsetList

# %%
cleanedList = [[] for _ in range(len(itemsetList))]

for i in range(len(itemsetList)):
    for item in itemsetList[i]:
        if item in cleanedList[i]:
            continue
        else:
            cleanedList[i].append(item)

# cleanedList

# %%
te = TransactionEncoder()
te_ary = te.fit(cleanedList).transform(cleanedList)

# %%
df_try = pd.DataFrame(te_ary, columns=te.columns_)
df_try
# Out:
#     Considerable  Critical  No or Low  Significant
# 0           True     False       True         True
# 1           True     False       True         True
# 2           True     False       True         True
# 3           True     False      False        False
# 4           True      True      False         True
# 5           True      True       True         True
# 6           True      True       True         True
# 7           True     False       True        False
# 8           True      True       True         True
# 9           True     False       True         True
# 10          True      True       True         True
# 11          True     False       True        False
# 12          True     False       True         True
# 13          True      True       True         True
# 14          True      True       True         True

# %%
frequent_itemsets = apriori(df_try, min_support=0.5, use_colnames=True)
frequent_itemsets.set_index(pd.Index(dfindex[:len(frequent_itemsets)]), inplace=True)

frequent_itemsets
# Out:
#                                 support  \
# Cloudy                         1.000000
# Heavy rain                     0.866667
# Heavy rain at times            0.800000
# Light drizzle                  0.866667
# Light rain                     0.800000
# Light rain shower              0.733333
# Moderate or heavy rain shower  0.733333
#
#                                                              itemsets
# Cloudy                                                 (Considerable)
# Heavy rain                                                (No or Low)
# Heavy rain at times                                     (Significant)
# Light drizzle                               (No or Low, Considerable)
# Light rain                                (Considerable, Significant)
# Light rain shower                            (No or Low, Significant)
# Moderate or heavy rain shower  (No or Low, Considerable, Significant)

# %%
res = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
res.set_index(pd.Index(dfindex[:len(res)]), inplace=True)

res = res[['antecedents', 'consequents', 'support', 'confidence']]
res
# Out:
#                                                antecedents  \
# Cloudy                                         (No or Low)
# Heavy rain                                  (Considerable)
# Heavy rain at times                         (Considerable)
# Light drizzle                                (Significant)
# Light rain                                     (No or Low)
# Light rain shower                            (Significant)
# Moderate or heavy rain shower    (No or Low, Considerable)
# Moderate rain                     (No or Low, Significant)
# Moderate rain at times         (Considerable, Significant)
# Overcast                                       (No or Low)
# Partly cloudy                               (Considerable)
# Patchy light drizzle                         (Significant)
#
#                                                consequents   support  \
# Cloudy                                      (Considerable)  0.866667
# Heavy rain                                     (No or Low)  0.866667
# Heavy rain at times                          (Significant)  0.800000
# Light drizzle                               (Considerable)  0.800000
# Light rain                                   (Significant)  0.733333
# Light rain shower                              (No or Low)  0.733333
# Moderate or heavy rain shower                (Significant)  0.733333
# Moderate rain                               (Considerable)  0.733333
# Moderate rain at times                         (No or Low)  0.733333
# Overcast                       (Considerable, Significant)  0.733333
# Partly cloudy                     (No or Low, Significant)  0.733333
# Patchy light drizzle             (No or Low, Considerable)  0.733333
#
#                                confidence
# Cloudy                           1.000000
# Heavy rain                       0.866667
# Heavy rain at times              0.800000
# Light drizzle                    1.000000
# Light rain                       0.846154
# Light rain shower                0.916667
# Moderate or heavy rain shower    0.846154
# Moderate rain                    1.000000
# Moderate rain at times           0.916667
# Overcast                         0.846154
# Partly cloudy                    0.733333
# Patchy light drizzle             0.916667
